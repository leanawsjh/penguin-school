# %%
import pandas as pd

# %%
df = pd.read_csv("../data/penguins.csv")

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.isna().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')>

# %%
df.species.value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
df.species.to_numpy()
# Out:
# array(['Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
# ...

# %%
df.island.value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
from functools import wraps
import pandas as pd

def loop_numeric_columns(func):
    @wraps(func)
    def wrapper(df, *args, **kwargs):
        global numeric_cols
        numeric_cols = df.select_dtypes(include="number").columns

        results = {}
        for col in numeric_cols:
            results[col] = func(df, col, *args, **kwargs)

        return results

    return wrapper   # ✅ THIS IS CRITICAL

# %%
@loop_numeric_columns
def plot_hist_box(df, column, bins=30):
    import matplotlib.pyplot as plt

    fig, axes = plt.subplots(1, 2, figsize=(10, 4))

    df[column].dropna().plot(kind="hist", bins=bins, ax=axes[0])
    df[column].dropna().plot(kind="box", ax=axes[1])

    plt.tight_layout()
    plt.show()

    return fig

# %%
plot_hist_box(df)
# Out:
# {'culmen_length_mm': <Figure size 1000x400 with 2 Axes>,
#  'culmen_depth_mm': <Figure size 1000x400 with 2 Axes>,
#  'flipper_length_mm': <Figure size 1000x400 with 2 Axes>,
#  'body_mass_g': <Figure size 1000x400 with 2 Axes>}

# %%
# coreclation matrix

df.select_dtypes(include="number").corr()
# Out:
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.235053           0.656181
# culmen_depth_mm           -0.235053         1.000000          -0.583851
# flipper_length_mm          0.656181        -0.583851           1.000000
# body_mass_g                0.595110        -0.471916           0.871202
#
#                    body_mass_g
# culmen_length_mm      0.595110
# culmen_depth_mm      -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
df[numeric_cols]
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# 0                39.1             18.7              181.0       3750.0
# 1                39.5             17.4              186.0       3800.0
# 2                40.3             18.0              195.0       3250.0
# 3                 NaN              NaN                NaN          NaN
# 4                36.7             19.3              193.0       3450.0
# ..                ...              ...                ...          ...
# 339               NaN              NaN                NaN          NaN
# 340              46.8             14.3              215.0       4850.0
# 341              50.4             15.7              222.0       5750.0
# 342              45.2             14.8              212.0       5200.0
# 343              49.9             16.1              213.0       5400.0
#
# [344 rows x 4 columns]

# %%
import seaborn as sns
sns.heatmap(df[numeric_cols].corr(), annot=True, square=True, )
# Out:
# <Axes: >
